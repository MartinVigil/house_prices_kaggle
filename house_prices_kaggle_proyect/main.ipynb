# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

train_df_c = train_df.copy()
test_df_c = test_df.copy()

# %%
#VISTA GENERAL

# %%
train_df_c.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df_c.shape
# Out:
# (1460, 81)

# %%
train_df_c.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_df_c.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_df_c.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#variables con datos faltantes en train_df

# %%
train_df_c.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
#ANALISIS EXPLORATORIO DE DATOS

# %%
#distribucion de los datos en la variable a predecir (SalePrice)

# %%
sns.displot(train_df,x='SalePrice')

# %%
#vista general de la distribucion de los datos en las variables numericas

# %%
num_cols = train_df.select_dtypes(exclude='O')

# %%
for i in num_cols.columns:
    num_cols.boxplot(column=i)
    plt.show()

# %%
#PREPROCESAMIENTO DE LOS DATOS

# %%
train_df_c = train_df_c.drop(columns=[a for a in train_df_c.columns if (train_df_c[a].isna().sum()/train_df_c.shape[0]) > 0.20],axis=0)
train_df_c = train_df_c.drop(columns='Id')

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder

train_cat_cols = train_df_c.select_dtypes(include='O')
num_cols = train_df_c.select_dtypes(exclude='O')

prep_train = train_df_c.copy()

imputer_categorical = SimpleImputer(strategy='most_frequent')
prep_train[train_cat_cols.columns] = pd.DataFrame(imputer_categorical.fit_transform(prep_train[train_cat_cols.columns]))

prep_train.columns = train_df_c.columns

imputer_num = SimpleImputer()
prep_train[num_cols.columns] = pd.DataFrame(imputer_num.fit_transform(prep_train[num_cols.columns]))

prep_train.columns = train_df_c.columns

encoder = OrdinalEncoder()
prep_train[train_cat_cols.columns] = pd.DataFrame(encoder.fit_transform(prep_train[train_cat_cols.columns]))

prep_train.columns = train_df_c.columns

prep_train
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0           60.0       3.0         65.0   8450.0     1.0       3.0
# 1           20.0       3.0         80.0   9600.0     1.0       3.0
# 2           60.0       3.0         68.0  11250.0     1.0       0.0
# 3           70.0       3.0         60.0   9550.0     1.0       0.0
# 4           60.0       3.0         84.0  14260.0     1.0       0.0
# ...          ...       ...          ...      ...     ...       ...
# 1455        60.0       3.0         62.0   7917.0     1.0       3.0
# 1456        20.0       3.0         85.0  13175.0     1.0       3.0
# 1457        70.0       3.0         66.0   9042.0     1.0       3.0
# 1458        20.0       3.0         68.0   9717.0     1.0       3.0
# 1459        20.0       3.0         75.0   9937.0     1.0       3.0
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  EnclosedPorch  \
# 0             3.0        0.0        4.0        0.0  ...            0.0
# ...

# %%
#normalizacion de las variables sesgadas

# %%
from scipy import stats

norm = [x for x in prep_train[num_cols.columns] if abs(prep_train[x].skew()) > 0.5]

for x in prep_train[norm]:
    prep_train[x] = np.log1p(prep_train[x])

# %%
prep_train.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'MSZoning'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'Street'}>,
#         <Axes: title={'center': 'LotShape'}>,
#         <Axes: title={'center': 'LandContour'}>,
#         <Axes: title={'center': 'Utilities'}>,
#         <Axes: title={'center': 'LotConfig'}>],
#        [<Axes: title={'center': 'LandSlope'}>,
#         <Axes: title={'center': 'Neighborhood'}>,
#         <Axes: title={'center': 'Condition1'}>,
#         <Axes: title={'center': 'Condition2'}>,
#         <Axes: title={'center': 'BldgType'}>,
#         <Axes: title={'center': 'HouseStyle'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>],
#        [<Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'RoofStyle'}>,
# ...

# %%
#escalar

# %%
from mlxtend.preprocessing import minmax_scaling

for x in prep_train.columns:
    prep_train[x] = minmax_scaling(prep_train,columns=[x])

# %%
#correlacion entre las variables

# %%
fig,ax = plt.subplots(figsize=(15,12))
sns.heatmap(prep_train[num_cols.columns].corr())
# Out:
# <Axes: >

# %%
#variables mas correlacionadas con el precio

# %%
fig,ax = plt.subplots(figsize=(15,12))
sns.heatmap(prep_train.corr()[['SalePrice']].sort_values('SalePrice',ascending=False).head(20),annot=True)
# Out:
# <Axes: >

# %%
corr = prep_train.corr().nlargest(30,'SalePrice')['SalePrice'].index[1:]

# %%
#eleccion y aplicacion del modelo

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor

y = prep_train['SalePrice']
features = [a for a in prep_train.columns if a != 'SalePrice']
x = prep_train[features]

model = XGBRegressor()
model.fit(x,y)

print(f'Precision: {cross_val_score(model,x,y,cv=5).mean()}')
# Out:
# Precision: 0.8815976167089363
